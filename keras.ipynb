# %% [markdown]
# # use_keras
#
# Build a neural network with Keras to try to identify drawn digits.

# %%
import tkinter as tk
import numpy as np

# Geometry constants.
WINDOW_WID = 160
WINDOW_HGT = 380
FRAME1_WID = 150
PADX = 5
NETWORK_CANVAS_WID = WINDOW_WID - FRAME1_WID - 4 * PADX
NETWORK_CANVAS_HGT = WINDOW_HGT - 2 * PADX
NUM_ROWS = 8
NUM_COLS = 6
CELL_WID = 20
CELL_HGT = CELL_WID
MARGIN = 5

class App:
    # Create and manage the tkinter interface.
    def __init__(self):
        self.network = None

        # Make the main interface.
        self.window = tk.Tk()
        self.window.title('digit_identification')
        self.window.protocol('WM_DELETE_WINDOW', self.kill_callback)
        self.window.geometry(f'{WINDOW_WID}x{WINDOW_HGT}')

        # Initially we have nothing to draw.
        self.polyline = None
        self.points = []

        # Build the UI.
        self.build_ui()

        # Build and train the neural network.
        self.make_trained_model()

        # Display the window.
        self.window.focus_force()
        self.window.mainloop()

    # Redraw the digit-drawing area.
    def redraw(self):
        # Remove old polyline.
        self.grid_canvas.delete(self.polyline)
        self.polyline = None

        # Draw current points.
        if len(self.points) > 1:
            self.polyline = self.grid_canvas.create_line(self.points, fill='black')

    def build_ui(self):
        # Make controls to define the network.
        frame1 = tk.Frame(self.window, width=FRAME1_WID)
        frame1.pack(side=tk.LEFT, expand=False, fill=tk.Y, padx=PADX)
        frame1.pack_propagate(False)

        frame2 = tk.Frame(self.window)
        frame2.pack(side=tk.LEFT, expand=True, fill=tk.BOTH, padx=PADX)

        # Make the drawing canvas.
        canvas_wid = NUM_COLS * CELL_WID + 1
        canvas_hgt = NUM_ROWS * CELL_HGT + 1
        self.grid_canvas = tk.Canvas(frame1, bg='white',
            borderwidth=0, highlightthickness=0, relief=tk.SUNKEN, width=canvas_wid, height=canvas_hgt)
        self.grid_canvas.pack(side=tk.TOP, pady=5)
        self.grid_canvas.bind('<Button-1>', self.start_draw)
        self.grid_canvas.bind('<ButtonRelease-1>', self.end_draw)

        # Make grid lines.
        for r in range(NUM_ROWS + 1):
            self.grid_canvas.create_line(0, r * CELL_HGT, canvas_wid, r * CELL_HGT, fill='lime')
        for c in range(NUM_COLS + 1):
            self.grid_canvas.create_line(c * CELL_WID, 0, c * CELL_WID, canvas_hgt, fill='lime')

        # Make a big label to display results from the user drawing.
        self.user_result_var = tk.StringVar()
        self.user_result_label = tk.Label(frame1, font=('Calibri 80 normal'),
            textvariable=self.user_result_var)
        self.user_result_label.pack(side=tk.TOP)

        # Make a label to display accuracy.
        self.accuracy_var = tk.StringVar()
        self.accuracy_label = tk.Label(frame1, textvariable=self.accuracy_var)
        self.accuracy_label.pack(side=tk.TOP)

        # Make a label to display accuracy.
        self.val_accuracy_var = tk.StringVar()
        self.val_accuracy_label = tk.Label(frame1, textvariable=self.val_accuracy_var)
        self.val_accuracy_label.pack(side=tk.TOP)

    def start_draw(self, event):
        # Clear any previous result.
        self.user_result_var.set('')

        # Remove any previous drawing.
        self.points = []
        self.redraw()

        self.grid_canvas.bind('<B1-Motion>', self.save_point)

    def end_draw(self, event):
        self.grid_canvas.unbind('<B1-Motion>')

        # Evaluate the polyline.
        self.evaluate_polyline()

    def save_point(self, event):
        self.points.append((event.x, event.y))
        self.redraw()

    def kill_callback(self):
        self.window.destroy()

    # See which digit is most likely.
    def evaluate_polyline(self):
        # Set VERBOSE = True to see diagnostic output.
        VERBOSE = False

        # Convert the polyline into a list of cells touched.
        inputs = [ self.polyline_to_0_1_list() ]
        if VERBOSE:
            print(f'inputs: {inputs}')

        # Run the neural network.
        predictions = self.model.predict(inputs)
        if VERBOSE:
            print(f'predictions: {predictions}')

        # Find the index of the largest output value.
        best_i = 0
        best_value = predictions[0][0]
        for i in range(len(predictions[0])):
            if predictions[0][i] > best_value:
                best_i = i
                best_value = predictions[0][i]
        if VERBOSE:
            print(f'best_value: {best_value}')
            print(f'best_i: {best_i}')

        # Display the best result.
        self.user_result_var.set(f'{best_i}')

    # Convert the polyline into a list of 0s and 1s showing which cells were touched.
    def polyline_to_0_1_list(self):
        # Make a list holding all 0s.
        touched_list = [0 for i in range(NUM_ROWS * NUM_COLS)]

        # Mark the touched cells.
        for point in self.points:
            r = int(point[1] / CELL_HGT)
            c = int(point[0] / CELL_WID)
            if r >= 0 and r < NUM_ROWS and c >= 0 and c < NUM_COLS:
                index = r * NUM_COLS + c
                touched_list[index] = 1

        # Return the list.
        return touched_list

    # For the general approach, see:
    #     https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/
    # Note that the input layer is usually not counted in the number of layers so when
    # the article creates a "three-layer network" that's an input layer (not counted),
    # two hidden layers, and an output layer. We're only making one hidden layer.
    # Save the trained model in self.model and display the last accurracy value.
    def make_trained_model(self):
        # Set VERBOSE = True to see diagnostic output.
        VERBOSE = False
        SHOW_PLOTS = True
    
        #################
        # Load the data #
        #################
        import pandas as pd
    
        # Read the data into a dataframe.
        df = pd.read_csv('digit_data.csv')
    
        # Print the shape of the data. It should be 79 rows with 58 columns.
        if VERBOSE:
            print(f'df.shape: {df.shape}')
    
        # Split data into training and validation sets.
        # (This would work better with many more rows.)
        from sklearn.model_selection import train_test_split
        TEST_FRACTION = 0.2
        train_df, test_df = train_test_split(df, test_size=TEST_FRACTION)
        if VERBOSE:
            print(
                f'Using {len(train_df)} training samples '
                f'and {len(test_df)} test samples'
            )
    
        # The input data includes columns 0 through 9.
        # The output data includes columns 10 through 58.
        # Both the inputs and outputs are vectors so they are capitalized.
        # (I.e. there are multiple inputs and outputs for each data sample.)
        # Get the inputs in columns 10 through 58.
        train_X = train_df.iloc[:, 10:59]
        test_X = test_df.iloc[:, 10:59]

        # Get the outputs in columns 0 through 9.
        train_Y = train_df.iloc[:, 0:10]
        test_Y = test_df.iloc[:, 0:10]
    
        if VERBOSE:
            # Print the test inputs and outputs to verify that it makes sense.
            print('test_df:')
            display(test_df)
            print('test_X:')
            display(test_X)
            print('test_Y:')
            display(test_Y)
    
        # Build a network with an input layer, one hidden layer, and an output layer.
        from tensorflow.keras.models import Sequential
        from tensorflow.keras.layers import Dense
        NUM_INPUTS = 48
        NUM_HIDDEN = 10
        NUM_OUTPUTS = 10
        model = Sequential()
    
        # Define the input and hidden layer. (The first layer also defines the input layer.)
        # "Dense" means each neuron is connected to every input.
        # Parameters:
        #     NUM_HIDDEN    This layer contains NUM_HIDDEN neurons.
        #     input_shape   Each neuron's inputs have NUM_INPUTS inputs. The trailing
        #                   comma makes this a list containing the single value NUM_INPUTS.
        #     activation    Use the ReLU activation function. These days, the rectified linear
        #                   unit (ReLU) activation function is in vogue for non-output layers.
        #     use_bias      We want to use bias. (This is the default.)
        model.add(Dense(NUM_HIDDEN, input_shape=(NUM_INPUTS,), activation='relu', use_bias=True))
    
        # Define the output layer.
        # Many models use a sigmoid activation function to map the result to 0 to 1.
        model.add(Dense(NUM_OUTPUTS, activation='sigmoid'))
    
        # Compile the model.
        model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
        if VERBOSE:
            print('Compiled')

        # Train the model.
        NUM_EPOCHS = 400
        BATCH_SIZE = 10
        # Other parameters:
        #    verbose=0       No progress reports
        #    shffle=False    Do not shuffle data before each epoch
        history = model.fit(train_X, train_Y, validation_data=(test_X, test_Y), epochs=NUM_EPOCHS, batch_size=BATCH_SIZE)
        if VERBOSE:
            print('Trained')
    
        if SHOW_PLOTS:
            # Plot the loss and accuracy during training.
            from matplotlib import pyplot

            # Draw plots in a new window.
            # %matplotlib qt

            # Plot loss.
            pyplot.figure()
            pyplot.title('Loss')
            pyplot.plot(history.history['loss'], label='train')
            pyplot.plot(history.history['val_loss'], label='test')
            pyplot.legend()
            pyplot.show()

            # Plot accuracy.
            pyplot.figure()
            pyplot.title('Accuracy')
            pyplot.plot(history.history['accuracy'], label='train')
            pyplot.plot(history.history['val_accuracy'], label='validate')
            pyplot.legend()
            pyplot.show()
    
        # Display the final accurracy and val_accuracy values.
        accuracy = history.history.get('accuracy')[-1]
        self.accuracy_var.set(f'Accuracy: {accuracy:.2%}')
        val_accuracy = history.history.get('val_accuracy')[-1]
        self.val_accuracy_var.set(f'Val Accuracy: {val_accuracy:.2%}')
    
        # Save the trained model.
        self.model = model

# %%
App()
# Out:
# Epoch 1/400
# 7/7 [==============================] - 0s 26ms/step - loss: 0.2523 - accuracy: 0.0794 - val_loss: 0.2504 - val_accuracy: 0.0625
# Epoch 2/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2360 - accuracy: 0.0794 - val_loss: 0.2369 - val_accuracy: 0.0625
# Epoch 3/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2210 - accuracy: 0.0952 - val_loss: 0.2248 - val_accuracy: 0.0625
# Epoch 4/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2078 - accuracy: 0.1270 - val_loss: 0.2128 - val_accuracy: 0.0625
# Epoch 5/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1953 - accuracy: 0.1270 - val_loss: 0.2009 - val_accuracy: 0.0625
# Epoch 6/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1837 - accuracy: 0.1270 - val_loss: 0.1897 - val_accuracy: 0.1250
# Epoch 7/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1733 - accuracy: 0.1111 - val_loss: 0.1795 - val_accuracy: 0.0625
# Epoch 8/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1636 - accuracy: 0.1111 - val_loss: 0.1701 - val_accuracy: 0.0625
# Epoch 9/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1545 - accuracy: 0.1111 - val_loss: 0.1612 - val_accuracy: 0.0625
# Epoch 10/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1460 - accuracy: 0.1111 - val_loss: 0.1523 - val_accuracy: 0.0625
# Epoch 11/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1379 - accuracy: 0.1111 - val_loss: 0.1441 - val_accuracy: 0.1250
# Epoch 12/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1306 - accuracy: 0.1270 - val_loss: 0.1368 - val_accuracy: 0.1250
# Epoch 13/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.
400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 0.9206 - val_loss: 0.0366 - val_accuracy: 0.7500
# Epoch 211/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9206 - val_loss: 0.0365 - val_accuracy: 0.7500
# Epoch 212/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0136 - accuracy: 0.9206 - val_loss: 0.0365 - val_accuracy: 0.7500
# Epoch 213/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0135 - accuracy: 0.9206 - val_loss: 0.0364 - val_accuracy: 0.7500
# Epoch 214/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 0.9206 - val_loss: 0.0363 - val_accuracy: 0.7500
# Epoch 215/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0133 - accuracy: 0.9206 - val_loss: 0.0361 - val_accuracy: 0.7500
# Epoch 216/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.9206 - val_loss: 0.0360 - val_accuracy: 0.7500
# Epoch 217/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.9206 - val_loss: 0.0360 - val_accuracy: 0.7500
# Epoch 218/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 0.9206 - val_loss: 0.0359 - val_accuracy: 0.7500
# Epoch 219/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.9206 - val_loss: 0.0360 - val_accuracy: 0.7500
# Epoch 220/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.9206 - val_loss: 0.0360 - val_accuracy: 0.7500
# Epoch 221/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0127 - accuracy: 0.9206 - val_loss: 0.0359 - val_accuracy: 0.7500
# Epoch 222/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0126 - accuracy: 0.9206 - val_loss: 0.0359 - val_accuracy: 0.7500
# Epoch 223/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0125 - accuracy: 0.9206 - val_loss: 0.0358 - val_accuracy: 0.7500
# Epoch 224/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0124 - accuracy: 0.9206 - val_loss: 0.0357 - val_accuracy: 0.7500
# Epoch 225/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0124 - accuracy: 0.9206 - val_loss: 0.0355 - val_accuracy: 0.7500
# Epoch 226/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0123 - accuracy: 0.9206 - val_loss: 0.0355 - val_accuracy: 0.7500
# Epoch 227/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 0.9206 - val_loss: 0.0355 - val_accuracy: 0.7500
# Epoch 228/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 0.9206 - val_loss: 0.0355 - val_accuracy: 0.7500
# Epoch 229/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0120 - accuracy: 0.9206 - val_loss: 0.0355 - val_accuracy: 0.7500
# Epoch 230/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0120 - accuracy: 0.9206 - val_loss: 0.0354 - val_accuracy: 0.7500
# Epoch 231/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0119 - accuracy: 0.9206 - val_loss: 0.0353 - val_accuracy: 0.7500
# Epoch 232/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 0.9206 - val_loss: 0.0353 - val_accuracy: 0.7500
# Epoch 233/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 0.9206 - val_loss: 0.0353 - val_accuracy: 0.7500
# Epoch 234/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 0.9206 - val_loss: 0.0352 - val_accuracy: 0.7500
# Epoch 235/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 0.9206 - val_loss: 0.0352 - val_accuracy: 0.7500
# Epoch 236/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 0.9206 - val_loss: 0.0351 - val_accuracy: 0.7500
# Epoch 237/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 0.9206 - val_loss: 0.0351 - val_accuracy: 0.8125
# Epoch 238/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 0.9206 - val_loss: 0.0351 - val_accuracy: 0.8125
# Epoch 239/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 0.9206 - val_loss: 0.0352 - val_accuracy: 0.8125
# Epoch 240/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0114 - accuracy: 0.9206 - val_loss: 0.0351 - val_accuracy: 0.8125
# Epoch 241/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0113 - accuracy: 0.9206 - val_loss: 0.0350 - val_accuracy: 0.8125
# Epoch 242/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0113 - accuracy: 0.9206 - val_loss: 0.0349 - val_accuracy: 0.8125
# Epoch 243/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0112 - accuracy: 0.9206 - val_loss: 0.0350 - val_accuracy: 0.8125
# Epoch 244/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9206 - val_loss: 0.0349 - val_accuracy: 0.8125
# Epoch 245/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9206 - val_loss: 0.0348 - val_accuracy: 0.8125
# Epoch 246/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0110 - accuracy: 0.9206 - val_loss: 0.0348 - val_accuracy: 0.8125
# Epoch 247/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9206 - val_loss: 0.0347 - val_accuracy: 0.8125
# Epoch 248/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 0.9206 - val_loss: 0.0346 - val_accuracy: 0.8125
# Epoch 249/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9206 - val_loss: 0.0346 - val_accuracy: 0.8125
# Epoch 250/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0108 - accuracy: 0.9206 - val_loss: 0.0346 - val_accuracy: 0.8125
# Epoch 251/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0108 - accuracy: 0.9206 - val_loss: 0.0345 - val_accuracy: 0.8125
# Epoch 252/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0108 - accuracy: 0.9206 - val_loss: 0.0344 - val_accuracy: 0.8125
# Epoch 253/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9206 - val_loss: 0.0344 - val_accuracy: 0.8125
# Epoch 254/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9206 - val_loss: 0.0344 - val_accuracy: 0.8125
# Epoch 255/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0106 - accuracy: 0.9206 - val_loss: 0.0343 - val_accuracy: 0.8125
# Epoch 256/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0106 - accuracy: 0.9206 - val_loss: 0.0343 - val_accuracy: 0.8125
# Epoch 257/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0106 - accuracy: 0.9206 - val_loss: 0.0342 - val_accuracy: 0.8125
# Epoch 258/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0105 - accuracy: 0.9206 - val_loss: 0.0342 - val_accuracy: 0.8125
# Epoch 259/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0105 - accuracy: 0.9206 - val_loss: 0.0342 - val_accuracy: 0.8125
# Epoch 260/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9206 - val_loss: 0.0342 - val_accuracy: 0.8125
# Epoch 261/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9206 - val_loss: 0.0341 - val_accuracy: 0.8125
# Epoch 262/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 0.9206 - val_loss: 0.0341 - val_accuracy: 0.8125
# Epoch 263/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0103 - accuracy: 0.9206 - val_loss: 0.0340 - val_accuracy: 0.8125
# Epoch 264/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0103 - accuracy: 0.9206 - val_loss: 0.0339 - val_accuracy: 0.8125
# Epoch 265/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 0.9206 - val_loss: 0.0339 - val_accuracy: 0.8125
# Epoch 266/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9206 - val_loss: 0.0339 - val_accuracy: 0.8125
# Epoch 267/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9206 - val_loss: 0.0339 - val_accuracy: 0.8125
# Epoch 268/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9206 - val_loss: 0.0339 - val_accuracy: 0.8125
# Epoch 269/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9206 - val_loss: 0.0338 - val_accuracy: 0.8125
# Epoch 270/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9206 - val_loss: 0.0338 - val_accuracy: 0.8125
# Epoch 271/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0101 - accuracy: 0.9206 - val_loss: 0.0338 - val_accuracy: 0.8125
# Epoch 272/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9206 - val_loss: 0.0337 - val_accuracy: 0.8125
# Epoch 273/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9206 - val_loss: 0.0337 - val_accuracy: 0.8125
# Epoch 274/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9206 - val_loss: 0.0336 - val_accuracy: 0.8125
# Epoch 275/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9206 - val_loss: 0.0336 - val_accuracy: 0.8125
# Epoch 276/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0099 - accuracy: 0.9206 - val_loss: 0.0336 - val_accuracy: 0.8125
# Epoch 277/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9206 - val_loss: 0.0335 - val_accuracy: 0.8125
# Epoch 278/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0099 - accuracy: 0.9206 - val_loss: 0.0335 - val_accuracy: 0.8125
# Epoch 279/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0098 - accuracy: 0.9206 - val_loss: 0.0335 - val_accuracy: 0.8125
# Epoch 280/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0098 - accuracy: 0.9206 - val_loss: 0.0334 - val_accuracy: 0.8125
# Epoch 281/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 0.9206 - val_loss: 0.0334 - val_accuracy: 0.8125
# Epoch 282/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0097 - accuracy: 0.9206 - val_loss: 0.0334 - val_accuracy: 0.8125
# Epoch 283/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0097 - accuracy: 0.9206 - val_loss: 0.0334 - val_accuracy: 0.8125
# Epoch 284/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0097 - accuracy: 0.9206 - val_loss: 0.0333 - val_accuracy: 0.8125
# Epoch 285/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0097 - accuracy: 0.9206 - val_loss: 0.0333 - val_accuracy: 0.8125
# Epoch 286/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9206 - val_loss: 0.0333 - val_accuracy: 0.8125
# Epoch 287/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9206 - val_loss: 0.0333 - val_accuracy: 0.8125
# Epoch 288/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9206 - val_loss: 0.0333 - val_accuracy: 0.8125
# Epoch 289/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9206 - val_loss: 0.0332 - val_accuracy: 0.8125
# Epoch 290/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 0.9206 - val_loss: 0.0331 - val_accuracy: 0.8125
# Epoch 291/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0095 - accuracy: 0.9206 - val_loss: 0.0332 - val_accuracy: 0.8125
# Epoch 292/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0095 - accuracy: 0.9206 - val_loss: 0.0331 - val_accuracy: 0.8125
# Epoch 293/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9206 - val_loss: 0.0331 - val_accuracy: 0.8125
# Epoch 294/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9206 - val_loss: 0.0330 - val_accuracy: 0.8125
# Epoch 295/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9206 - val_loss: 0.0330 - val_accuracy: 0.8125
# Epoch 296/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 0.9206 - val_loss: 0.0330 - val_accuracy: 0.8125
# Epoch 297/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 0.9206 - val_loss: 0.0329 - val_accuracy: 0.8125
# Epoch 298/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 0.9206 - val_loss: 0.0329 - val_accuracy: 0.8125
# Epoch 299/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0092 - accuracy: 0.9206 - val_loss: 0.0328 - val_accuracy: 0.8125
# Epoch 300/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 0.9206 - val_loss: 0.0327 - val_accuracy: 0.8125
# Epoch 301/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0091 - accuracy: 0.9206 - val_loss: 0.0327 - val_accuracy: 0.8125
# Epoch 302/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9206 - val_loss: 0.0327 - val_accuracy: 0.8125
# Epoch 303/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0091 - accuracy: 0.9365 - val_loss: 0.0327 - val_accuracy: 0.8125
# Epoch 304/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0090 - accuracy: 0.9365 - val_loss: 0.0326 - val_accuracy: 0.8125
# Epoch 305/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0090 - accuracy: 0.9365 - val_loss: 0.0326 - val_accuracy: 0.8125
# Epoch 306/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 0.9365 - val_loss: 0.0326 - val_accuracy: 0.8125
# Epoch 307/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 0.9365 - val_loss: 0.0326 - val_accuracy: 0.8125
# Epoch 308/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9365 - val_loss: 0.0325 - val_accuracy: 0.8125
# Epoch 309/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9365 - val_loss: 0.0324 - val_accuracy: 0.8125
# Epoch 310/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9524 - val_loss: 0.0323 - val_accuracy: 0.8125
# Epoch 311/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9683 - val_loss: 0.0323 - val_accuracy: 0.8125
# Epoch 312/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9683 - val_loss: 0.0322 - val_accuracy: 0.8125
# Epoch 313/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9683 - val_loss: 0.0322 - val_accuracy: 0.8125
# Epoch 314/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9683 - val_loss: 0.0322 - val_accuracy: 0.8125
# Epoch 315/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9683 - val_loss: 0.0322 - val_accuracy: 0.8125
# Epoch 316/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0084 - accuracy: 0.9683 - val_loss: 0.0321 - val_accuracy: 0.8125
# Epoch 317/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0084 - accuracy: 0.9683 - val_loss: 0.0322 - val_accuracy: 0.8125
# Epoch 318/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9683 - val_loss: 0.0322 - val_accuracy: 0.8125
# Epoch 319/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9683 - val_loss: 0.0322 - val_accuracy: 0.8125
# Epoch 320/400
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0082 - accuracy: 0.9683 - val_loss: 0.0321 - val_accuracy: 0.8125
# Epoch 321/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 0.9683 - val_loss: 0.0321 - val_accuracy: 0.8125
# Epoch 322/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9683 - val_loss: 0.0321 - val_accuracy: 0.8125
# Epoch 323/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0081 - accuracy: 0.9683 - val_loss: 0.0320 - val_accuracy: 0.8125
# Epoch 324/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 0.9683 - val_loss: 0.0319 - val_accuracy: 0.8125
# Epoch 325/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 0.9683 - val_loss: 0.0318 - val_accuracy: 0.8125
# Epoch 326/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0079 - accuracy: 0.9683 - val_loss: 0.0318 - val_accuracy: 0.8125
# Epoch 327/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9683 - val_loss: 0.0318 - val_accuracy: 0.8125
# Epoch 328/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9683 - val_loss: 0.0318 - val_accuracy: 0.8125
# Epoch 329/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9683 - val_loss: 0.0317 - val_accuracy: 0.8125
# Epoch 330/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0077 - accuracy: 0.9683 - val_loss: 0.0317 - val_accuracy: 0.8125
# Epoch 331/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9683 - val_loss: 0.0317 - val_accuracy: 0.8125
# Epoch 332/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0076 - accuracy: 0.9683 - val_loss: 0.0316 - val_accuracy: 0.8125
# Epoch 333/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 0.9683 - val_loss: 0.0316 - val_accuracy: 0.8125
# Epoch 334/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9683 - val_loss: 0.0316 - val_accuracy: 0.8125
# Epoch 335/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9683 - val_loss: 0.0315 - val_accuracy: 0.8125
# Epoch 336/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0074 - accuracy: 0.9683 - val_loss: 0.0315 - val_accuracy: 0.8125
# Epoch 337/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0074 - accuracy: 0.9683 - val_loss: 0.0315 - val_accuracy: 0.8125
# Epoch 338/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 0.9683 - val_loss: 0.0314 - val_accuracy: 0.8125
# Epoch 339/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9683 - val_loss: 0.0314 - val_accuracy: 0.8125
# Epoch 340/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9683 - val_loss: 0.0313 - val_accuracy: 0.8125
# Epoch 341/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 0.9683 - val_loss: 0.0313 - val_accuracy: 0.8125
# Epoch 342/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9683 - val_loss: 0.0313 - val_accuracy: 0.8125
# Epoch 343/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0070 - accuracy: 0.9683 - val_loss: 0.0314 - val_accuracy: 0.8125
# Epoch 344/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9683 - val_loss: 0.0313 - val_accuracy: 0.8125
# Epoch 345/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9683 - val_loss: 0.0312 - val_accuracy: 0.8125
# Epoch 346/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 0.9683 - val_loss: 0.0311 - val_accuracy: 0.8125
# Epoch 347/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9683 - val_loss: 0.0311 - val_accuracy: 0.8125
# Epoch 348/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0067 - accuracy: 0.9683 - val_loss: 0.0311 - val_accuracy: 0.8750
# Epoch 349/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0067 - accuracy: 0.9683 - val_loss: 0.0311 - val_accuracy: 0.8750
# Epoch 350/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9841 - val_loss: 0.0310 - val_accuracy: 0.8125
# Epoch 351/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9683 - val_loss: 0.0311 - val_accuracy: 0.8125
# Epoch 352/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9683 - val_loss: 0.0311 - val_accuracy: 0.8125
# Epoch 353/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0065 - accuracy: 0.9683 - val_loss: 0.0310 - val_accuracy: 0.8125
# Epoch 354/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0064 - accuracy: 0.9683 - val_loss: 0.0310 - val_accuracy: 0.8125
# Epoch 355/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9683 - val_loss: 0.0309 - val_accuracy: 0.8125
# Epoch 356/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0063 - accuracy: 0.9683 - val_loss: 0.0307 - val_accuracy: 0.8750
# Epoch 357/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0063 - accuracy: 0.9841 - val_loss: 0.0307 - val_accuracy: 0.8750
# Epoch 358/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 0.9841 - val_loss: 0.0306 - val_accuracy: 0.8750
# Epoch 359/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9841 - val_loss: 0.0306 - val_accuracy: 0.8750
# Epoch 360/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9841 - val_loss: 0.0305 - val_accuracy: 0.8750
# Epoch 361/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9841 - val_loss: 0.0305 - val_accuracy: 0.8750
# Epoch 362/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9841 - val_loss: 0.0306 - val_accuracy: 0.8750
# Epoch 363/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9841 - val_loss: 0.0306 - val_accuracy: 0.8750
# Epoch 364/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9841 - val_loss: 0.0306 - val_accuracy: 0.8125
# Epoch 365/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0059 - accuracy: 0.9841 - val_loss: 0.0306 - val_accuracy: 0.8125
# Epoch 366/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9841 - val_loss: 0.0305 - val_accuracy: 0.8125
# Epoch 367/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 0.9841 - val_loss: 0.0303 - val_accuracy: 0.8750
# Epoch 368/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9841 - val_loss: 0.0303 - val_accuracy: 0.8750
# Epoch 369/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9841 - val_loss: 0.0302 - val_accuracy: 0.9375
# Epoch 370/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9841 - val_loss: 0.0302 - val_accuracy: 0.9375
# Epoch 371/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9841 - val_loss: 0.0302 - val_accuracy: 0.9375
# Epoch 372/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9841 - val_loss: 0.0302 - val_accuracy: 0.9375
# Epoch 373/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9841 - val_loss: 0.0301 - val_accuracy: 0.9375
# Epoch 374/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 0.9841 - val_loss: 0.0302 - val_accuracy: 0.9375
# Epoch 375/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 0.9841 - val_loss: 0.0301 - val_accuracy: 0.9375
# Epoch 376/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9375
# Epoch 377/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 0.9375
# Epoch 378/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 0.9375
# Epoch 379/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0297 - val_accuracy: 0.9375
# Epoch 380/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0296 - val_accuracy: 0.9375
# Epoch 381/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 0.9375
# Epoch 382/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9375
# Epoch 383/400
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 0.9375
# Epoch 384/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 0.9375
# Epoch 385/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9375
# Epoch 386/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0292 - val_accuracy: 0.9375
# Epoch 387/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 0.9375
# Epoch 388/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 0.9375
# Epoch 389/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 0.9375
# Epoch 390/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9375
# Epoch 391/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9375
# Epoch 392/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0288 - val_accuracy: 0.9375
# Epoch 393/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0286 - val_accuracy: 0.9375
# Epoch 394/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9375
# Epoch 395/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9375
# Epoch 396/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9375
# Epoch 397/400
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9375
# Epoch 398/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 0.9375
# Epoch 399/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9375
# Epoch 400/400
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9375
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
